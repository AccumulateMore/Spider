# %% [markdown]
# # 爬虫基本知识

# %% [markdown]
# # 1. 爬虫基本概念

# %% [markdown]
# ① 网络爬虫又称网络蜘蛛、网络机器人等，可以自动化浏览网络中的信息，当然浏览信息的时候需要按照所制定的相应规则进行，即网络爬虫算法。
#
# ② 我们可以利用爬虫技术，自动地从互联网中获取我们感兴趣的内容，并将这些数据内容爬取回来，作为我们的数据源，从而进行更深层次的数据分析，并获得更多有价值的信息。
#
# ③ 只要是浏览器能做的事情，原则上，爬虫都能够做。在大数据时代，这一技能是必不可少的。

# %% [markdown]
# # 2. 网页基本概念

# %% [markdown]
# ## 2.1 网页文档含义

# %% [markdown]
# ① 每一个网页都是一份 HTML文档，全称叫 hypertext markup language，是一种文本标记语言，标签含义如下图所示：

# %%
<!DOCTYPE html> 声明为HTML5 文档
<html> 元素是HTML网页的根元素
<head> 元素包含了文档的元(meta) 数据，如<meta charset="utf-8">定义网页编码格式为utf-8        
<title> 元素描述了文档的标题
<body> 元素包含了可见的页面内容
<h1> 元素定义一个大标题
<p> 元素定义一个段落

# %% [markdown]
# ## 2.2 新建网页文档

# %% [markdown]
# ① 新建一个txt文件，写入html内容，把txt后缀改为html，就会变为网页格式，可以用记事本打开，如下图示。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 2.3 右键网页文档信息

# %% [markdown]
# ① 打开一个网页，即是通过了HTTP协议，对一个资源进行了请求，返还你一份HTML文档，然后浏览器进行文档的渲染，这样，就形成了一个网页。如下图所示，打开任意一个网页右键点击"显示网页源代码"，可以获得以下内容。
#
# ② HTML 标记标签通常被称为 HTML 标签(HTML tag)，HTML 标签由尖括号包围的关键词。
#
# 1. 比如$<html>和</html>$，HTML 标签通常是成对出现的。
# 2. 比如$<b>和</b>$，标签对中的第一个标签是开始标签，第二个标签是结束标签。
# 3. 开始和结束标签也被称为开放标签和闭合标签。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 2.4 网络爬虫获取文档

# %% [markdown]
# ③ 我们只需要模拟浏览器，发送一份请求，获得这份文档，不通过渲染直接从文档中抽取出我们需要的内容就好。

# %% [markdown]
# # 3. 爬虫方法

# %% [markdown]
# ## 3.1 两种爬虫方法

# %% [markdown]
# ① 一般爬虫分为两种方法：通用搜索引擎爬虫和聚焦爬虫。一般企业都是做聚焦爬虫，爬我们需要的内容。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 5.2 通用搜索引擎局爬虫限性

# %% [markdown]
# ① 通用搜索引擎爬虫的局限性
#
# 1. 通用搜索引擎爬虫所返回的网页里90%的内容无用。
# 2. 图片、音频、视频多媒体的内容通用搜索引擎无能无力。
# 3. 不同用户搜索的目的不全相同，但是返回内容相同。

# %% [markdown]
# # 4. Robots协议

# %% [markdown]
# ① Robots协议是Web站点和搜索引擎爬虫交互的一种方式。Robots.txt是存放在站点根目录下的一个纯文本文件。该文件可以指定搜索引擎爬虫只爬取指定的内容，或者禁止搜索引擎爬取网站的部分或全部内容。
#
# ② 当一个搜索引擎爬虫访问一个站点时，它会首先检查该站点根目录下是否存在robots.txt，如果存在，搜索引擎爬虫就会按照该文件中的内容来确定访问的范围；如果该文件不存在，那么搜索引擎爬虫就沿着链接抓取。
#
# ③ robots.txt必须放置在一个站点的根目录下，而且文件名必须全部小写。
#
# ④ 如果搜索引擎爬虫要访问的网站地址是World Wide Web Consortium (W3C) 那么robot.txt文件必须能够通过http://www.w3.org/robot.txt 打开并看到里面的内容。
#
# ⑤ robot.txt只是一个协议，如果搜索引擎爬虫的设计者不遵守这个协议网站管理员也无法阻止搜索引擎爬虫对某些页面的访问，但一般的搜索引擎爬虫都会遵循这些协议，而且网站管理员还可以通过其他方式来拒绝网络蜘蛛对某些网页的抓取。

# %% [markdown]
# # 5. request模块

# %% [markdown]
# ## 5.1 request基本概念

# %% [markdown]
# ① 爬虫用的是request模块
#
# 1. request的底层实现就是urllib模块。
# 2. request在python2和python3中通用，方法完全一样。
# 3. request简单易用。
# 4. request能够自动帮我吗解压(gzip压缩等)网页内容。
#
# ② request 的作用：发送网络请求，返回相应数据。

# %% [markdown]
# ## 5.2 request请求方法

# %% [markdown]
# ① request常用的有两种请求方法：get方法和post方法。

# %%
#各种请求方法
import requests
print(requests.get('http://httpbin.org/get'))    # 最主要的请求方法是get方法和post方法           
print(requests.post('http://httpbin.org/post'))  #常是用户要账号密码登陆的用的多谢
print(requests.put('http://httpbin.org/put'))
print(requests.delete('http://httpbin.org/delete'))
print(requests.head('http://httpbin.org/get'))
print(requests.options('http://httpbin.org/get'))
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>

# %% [markdown]
# # 6. 数据类型

# %% [markdown]
# ① 数据分两种形式：非结构化数据、结构化数据。
#
# 1. 非结构化数据html等
#
# 处理方法：正则表达式、Xpath。
#
# 2. 结构化数据：json、xml等
#
# 处理方法：转化为python数据类型。
